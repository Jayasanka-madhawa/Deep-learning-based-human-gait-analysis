# %% [markdown]
# ![fvector.png](attachment:fvector.png)

# %% [raw]
# #update this
#
# feature_matrix= [
#                                  [sT1]    step time-right
#                                  [sT2]    stride time-rights
#                                  [sT3]    stride frequency-right
#                                  [sT4]    swing time-right
#                                  [sT5]    step time-left
#                                  [sT6]    stride time-left
#                                  [sT7]    stride frequency-left
#                                  [sT8]    swing time-left
#                                  [sT9]    foot flat time
#                                  [sT10]   double support time
#                                  [sT11]   stance time ration
#                                  [sT12]   swing time ratio
#
#                                  [fT1]    step time-right
#                                  [fT2]    stride time-right
#                                  [fT3]    stride frequency-right
#                                  [fT4]    step time-left
#                                  [fT5]    stride time-leftt
#                                  [fT6]    stride frequency-left
#
#
#                 ]
